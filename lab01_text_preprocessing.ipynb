# %% [markdown]
# <a href="https://colab.research.google.com/github/MadisonJBollinger/lis5693/blob/main/lab01_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
#This will connect my account with the coding.
'gensim==4.3.1',
'matplotlib==3.8.4',
'numpy>=1.16',
'nltk==3.9.1',
'pandas>=2.0.3',
'pytesseract==0.3.10',
'regex==2023.6.3',
'requests==2.32.3',
'scikit-learn==1.5.1',
'scipy==1.11.1',
'seaborn==0.12.2',
'spacy==3.5.4',
'vadersentiment==3.3.2'
#These are the requested packages for the assignment.
# Out:
# Mounted at /content/drive
# 'vadersentiment==3.3.2'

# %% [markdown]
# <a href="https://colab.research.google.com/github/MadisonJBollinger/lis5693/blob/main/lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import altair as alt
# !pip install vl-convert-python


from vega_datasets import data as vega_data

# %%
import requests
import io

url = "https://raw.githubusercontent.com/manika-lamba/SP26-LIS4_5693/refs/heads/main/lab-assignments/lab-3/Seattle-Library_2015-2021.csv"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text

# %%
seattle_df = pd.read_csv(io.StringIO(text))
seattle_df.head()

# %%
seattle_df['Publisher'].value_counts().plot(kind='line')

# %%
source = pd.DataFrame({
    'a': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'],
    'b': [28, 55, 43, 91, 81, 53, 19, 87, 52]
})

alt.Chart(source).mark_bar().encode(
    x='a',
    y='b'
)

# %%
seattle_df['Publisher'].value_counts()

# %%
type(seattle_df['Publisher'].value_counts())

# %%
seattle_df['Publisher'].value_counts().rename_axis('Publisher').reset_index(name='counts')

# %%
source = seattle_df['Publisher'].value_counts().rename_axis('Publisher').reset_index(name='counts')
alt.Chart(source).mark_bar().encode(
    x='Publisher',
    y='counts'
)

# %% [markdown]
# The thing that did not go well for me was downloading the data into github to be able to utilize the data.
